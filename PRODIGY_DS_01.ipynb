# %% [markdown]
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_5607187.csv')
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
total_population=df[df['Indicator Code']=='SP.POP.TOTL']
total_population
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
total_population_sort = total_population.sort_values(by='2022',ascending=False)
total_population_sort
# Out:
#                Country Name Country Code     Indicator Name Indicator Code  \
# 259                   World          WLD  Population, total    SP.POP.TOTL
# 103        IDA & IBRD total          IBT  Population, total    SP.POP.TOTL
# 140     Low & middle income          LMY  Population, total    SP.POP.TOTL
# 156           Middle income          MIC  Population, total    SP.POP.TOTL
# 102               IBRD only          IBD  Population, total    SP.POP.TOTL
# ..                      ...          ...                ...            ...
# 255  British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 188                   Palau          PLW  Population, total    SP.POP.TOTL
# 179                   Nauru          NRU  Population, total    SP.POP.TOTL
# 245                  Tuvalu          TUV  Population, total    SP.POP.TOTL
# 110          Not classified          INX  Population, total    SP.POP.TOTL
#
# ...

# %%
top_ten_countries = total_population_sort.head(10)
print("Top Ten Countries Of Total Population:-")
print(top_ten_countries)
# Out:
# Top Ten Countries Of Total Population:-
#                    Country Name Country Code     Indicator Name  \
# 259                       World          WLD  Population, total
# 103            IDA & IBRD total          IBT  Population, total
# 140         Low & middle income          LMY  Population, total
# 156               Middle income          MIC  Population, total
# 102                   IBRD only          IBD  Population, total
# 62   Early-demographic dividend          EAR  Population, total
# 139         Lower middle income          LMC  Population, total
# 249         Upper middle income          UMC  Population, total
# 63          East Asia & Pacific          EAS  Population, total
# 142   Late-demographic dividend          LTE  Population, total
#
#     Indicator Code          1960          1961          1962          1963  \
# 259    SP.POP.TOTL  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09
# ...

# %%
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3

        va='bottom' if y>=0 else 'top'
        label= '()'.format(y)
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# Top ten Countries total population in the year 2022 and 2020

# %%
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# Top ten Countries total population in the year 1999 and 1989

# %%
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# Top ten Countries total population in the year 1960 and 2022

# %%
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2022',y="Country Name",hue="Country Name",data=top_ten_countries,palette="coolwarm",legend=False)
plt.title("Top Ten countries Of Total Population in 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
